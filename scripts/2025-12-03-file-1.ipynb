# %%
# %%bash
# git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file
# >..." to include in what will be committed)
# 	.2025-12-03-file-1.ipynb.sage-jupyter2
# 	2025-12-03-file
# -1.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %%bash
#
# git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file
# >..." to include in what will be committed)
# 	.2025-12-03-file-1.ipynb.sage-jupyter2
# 	2025-12-03-file
# -1.ipynb
# 	scripts/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %%bash
#
# git add .
# git commit -m ""
# git push
